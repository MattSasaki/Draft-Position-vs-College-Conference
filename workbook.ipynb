# %%
years = list(range(1989, 2023))

# %%
url_start = "https://www.basketball-reference.com/draft/NBA_{}.html"

# %%
import requests

for year in years:
    url = url_start.format(year)
    data = requests.get(url)
    
    with open("draft/{}.html".format(year), "w+") as f:
        f.write(data.text)

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
dfs = []
for year in years:
    with open("draft/{}.html".format(year)) as f:
        page = f.read()
    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_='over_header').decompose()
    draft_table = soup.find(id='stats')
    draft = pd.read_html(str(draft_table))[0]
    draft['Year'] = year
    
    dfs.append(draft)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       4     page = f.read()
#       5 soup = BeautifulSoup(page, "html.parser")
# ----> 6 soup.find('tr', class_='over_header').decompose()
#       7 draft_table = soup.find(id='stats')
#       8 draft = pd.read_html(str(draft_table))[0]
#
# AttributeError: 'NoneType' object has no attribute 'decompose'

# %%
drafts = pd.concat(dfs)

# %%
drafts
# Out:
#     Rk  Pk   Tm                Player       College Yrs     G     MP    PTS  \
# 0    1   1  SAC        Pervis Ellison    Louisville  11   474  11593   4494
# 1    2   2  LAC           Danny Ferry          Duke  13   917  18133   6439
# 2    3   3  SAS          Sean Elliott       Arizona  12   742  24502  10544
# 3    4   4  MIA             Glen Rice      Michigan  15  1000  34985  18336
# 4    5   5  CHH             J.R. Reid           UNC  11   672  15370   5680
# ..  ..  ..  ...                   ...           ...  ..   ...    ...    ...
# 57  56  56  PHI          Ray Spalding    Louisville   2    16    167     58
# 58  57  57  OKC          Kevin Hervey  UT Arlington   1    10     52     17
# 59  58  58  DEN          Thomas Welsh          UCLA   1    11     36     18
# 60  59  59  PHO           George King      Colorado   2     5     25      1
# 61  60  60  PHI  Kostas Antetokounmpo        Dayton   3    22     87     21
#
#      TRB  ...   FT%  MP.1 PTS.1 TRB.1 AST.1    WS  WS/48    BPM  VORP  Year
# 0   3170  ...  .689  24.5   9.5   6.7   1.5  21.8   .090   -0.5   4.4  1989
# 1   2550  ...  .840  19.8   7.0   2.8   1.3  34.8   .092   -0.9   4.9  1989
# 2   3204  ...  .799  33.0  14.2   4.3   2.6  55.7   .109    0.2  13.5  1989
# 3   4387  ...  .846  35.0  18.3   4.4   2.1  88.7   .122    0.8  24.9  1989
# 4   3381  ...  .716  22.9   8.5   5.0   1.0  22.5   .070   -2.9  -3.7  1989
# ..   ...  ...   ...   ...   ...   ...   ...   ...    ...    ...   ...   ...
# 57    52  ...  .286  10.4   3.6   3.3   0.3   0.1   .024   -6.2  -0.2  2018
# 58    12  ...   NaN   5.2   1.7   1.2   0.5  -0.1  -.085   -5.1   0.0  2018
# 59     4  ...  .500   3.3   1.6   0.4   0.5   0.1   .162    1.2   0.0  2018
# 60     6  ...  .500   5.0   0.2   1.2   0.0  -0.1  -.225  -17.2  -0.1  2018
# 61    23  ...  .474   4.0   1.0   1.0   0.1  -0.2  -.098   -9.9  -0.2  2018
#
# [1806 rows x 23 columns]

# %% [markdown]
# # Before this need to reset wifi to avoid rate limited

# %%
years2 = list(range(2019, 2023))

# %%
import requests

for year in years2:
    url = url_start.format(year)
    data = requests.get(url)
    
    with open("draft/{}.html".format(year), "w+") as f:
        f.write(data.text)

# %%
dfs2 = []
for year in years2:
    with open("draft/{}.html".format(year)) as f:
        page = f.read()
    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_='over_header').decompose()
    draft_table = soup.find(id='stats')
    draft = pd.read_html(str(draft_table))[0]
    draft['Year'] = year
    
    dfs2.append(draft)

# %%
drafts2 = pd.concat(dfs2)

# %%
drafts2
# Out:
#      Rk   Pk   Tm           Player       College  \
# 0     1    1  NOP  Zion Williamson          Duke
# 1     2    2  MEM        Ja Morant  Murray State
# 2     3    3  NYK       RJ Barrett          Duke
# 3     4    4  LAL  De'Andre Hunter      Virginia
# 4     5    5  CLE   Darius Garland    Vanderbilt
# ..  ...  ...  ...              ...           ...
# 57   56   56  CLE     Luke Travers           NaN
# 58   57   57  POR    Jabari Walker      Colorado
# 59   58   58  IND      Hugo Besson           NaN
# 60  NaN  NaN  NaN              NaN           NaN
# 61  NaN  NaN  NaN              NaN           NaN
#
#                                                   Yrs  \
# 0                                                   3
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                   4
# ..                                                ...
# 57                                                NaN
# 58                                                  1
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                     G  \
# 0                                                 114
# 1                                                 221
# 2                                                 234
# 3                                                 172
# 4                                                 215
# ..                                                ...
# 57                                                NaN
# 58                                                 25
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                    MP  \
# 0                                                3650
# 1                                                7117
# 2                                                7865
# 3                                                5316
# 4                                                7261
# ..                                                ...
# 57                                                NaN
# 58                                                222
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                   PTS  \
# 0                                                2941
# 1                                                4898
# 2                                                4187
# 3                                                2341
# 4                                                3867
# ..                                                ...
# 57                                                NaN
# 58                                                 58
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                   TRB  ...  \
# 0                                                 793  ...
# 1                                                1037  ...
# 2                                                1300  ...
# 3                                                 719  ...
# 4                                                 556  ...
# ..                                                ...  ...
# 57                                                NaN  ...
# 58                                                 64  ...
# 59                                                NaN  ...
# 60  Milwaukee Bucks forfeited their Second Round p...  ...
# 61      Miami Heat forfeited their Second Round pick.  ...
#
#                                                   FT%  \
# 0                                                .691
# 1                                                .754
# 2                                                .708
# 3                                                .792
# 4                                                .871
# ..                                                ...
# 57                                                NaN
# 58                                               .688
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                  MP.1  \
# 0                                                32.0
# 1                                                32.2
# 2                                                33.6
# 3                                                30.9
# 4                                                33.8
# ..                                                ...
# 57                                                NaN
# 58                                                8.9
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 PTS.1  \
# 0                                                25.8
# 1                                                22.2
# 2                                                17.9
# 3                                                13.6
# 4                                                18.0
# ..                                                ...
# 57                                                NaN
# 58                                                2.3
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 TRB.1  \
# 0                                                 7.0
# 1                                                 4.7
# 2                                                 5.6
# 3                                                 4.2
# 4                                                 2.6
# ..                                                ...
# 57                                                NaN
# 58                                                2.6
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 AST.1  \
# 0                                                 3.6
# 1                                                 7.3
# 2                                                 2.9
# 3                                                 1.5
# 4                                                 6.5
# ..                                                ...
# 57                                                NaN
# 58                                                0.6
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                    WS  \
# 0                                                14.5
# 1                                                17.5
# 2                                                 7.3
# 3                                                 4.2
# 4                                                 9.7
# ..                                                ...
# 57                                                NaN
# 58                                                0.3
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 WS/48  \
# 0                                                .190
# 1                                                .118
# 2                                                .045
# 3                                                .038
# 4                                                .064
# ..                                                ...
# 57                                                NaN
# 58                                               .068
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                   BPM  \
# 0                                                 5.2
# 1                                                 2.5
# 2                                                -2.1
# 3                                                -3.5
# 4                                                -0.7
# ..                                                ...
# 57                                                NaN
# 58                                               -3.8
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                  VORP  Year
# 0                                                 6.6  2019
# 1                                                 8.2  2019
# 2                                                -0.3  2019
# 3                                                -2.0  2019
# 4                                                 2.3  2019
# ..                                                ...   ...
# 57                                                NaN  2022
# 58                                               -0.1  2022
# 59                                                NaN  2022
# 60  Milwaukee Bucks forfeited their Second Round p...  2022
# 61      Miami Heat forfeited their Second Round pick.  2022
#
# [248 rows x 23 columns]

# %%
drafts_full = pd.concat([drafts, drafts2])

# %%
drafts_full
# Out:
#      Rk   Pk   Tm          Player     College  \
# 0     1    1  SAC  Pervis Ellison  Louisville
# 1     2    2  LAC     Danny Ferry        Duke
# 2     3    3  SAS    Sean Elliott     Arizona
# 3     4    4  MIA       Glen Rice    Michigan
# 4     5    5  CHH       J.R. Reid         UNC
# ..  ...  ...  ...             ...         ...
# 57   56   56  CLE    Luke Travers         NaN
# 58   57   57  POR   Jabari Walker    Colorado
# 59   58   58  IND     Hugo Besson         NaN
# 60  NaN  NaN  NaN             NaN         NaN
# 61  NaN  NaN  NaN             NaN         NaN
#
#                                                   Yrs  \
# 0                                                  11
# 1                                                  13
# 2                                                  12
# 3                                                  15
# 4                                                  11
# ..                                                ...
# 57                                                NaN
# 58                                                  1
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                     G  \
# 0                                                 474
# 1                                                 917
# 2                                                 742
# 3                                                1000
# 4                                                 672
# ..                                                ...
# 57                                                NaN
# 58                                                 25
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                    MP  \
# 0                                               11593
# 1                                               18133
# 2                                               24502
# 3                                               34985
# 4                                               15370
# ..                                                ...
# 57                                                NaN
# 58                                                222
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                   PTS  \
# 0                                                4494
# 1                                                6439
# 2                                               10544
# 3                                               18336
# 4                                                5680
# ..                                                ...
# 57                                                NaN
# 58                                                 58
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                   TRB  ...  \
# 0                                                3170  ...
# 1                                                2550  ...
# 2                                                3204  ...
# 3                                                4387  ...
# 4                                                3381  ...
# ..                                                ...  ...
# 57                                                NaN  ...
# 58                                                 64  ...
# 59                                                NaN  ...
# 60  Milwaukee Bucks forfeited their Second Round p...  ...
# 61      Miami Heat forfeited their Second Round pick.  ...
#
#                                                   FT%  \
# 0                                                .689
# 1                                                .840
# 2                                                .799
# 3                                                .846
# 4                                                .716
# ..                                                ...
# 57                                                NaN
# 58                                               .688
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                  MP.1  \
# 0                                                24.5
# 1                                                19.8
# 2                                                33.0
# 3                                                35.0
# 4                                                22.9
# ..                                                ...
# 57                                                NaN
# 58                                                8.9
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 PTS.1  \
# 0                                                 9.5
# 1                                                 7.0
# 2                                                14.2
# 3                                                18.3
# 4                                                 8.5
# ..                                                ...
# 57                                                NaN
# 58                                                2.3
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 TRB.1  \
# 0                                                 6.7
# 1                                                 2.8
# 2                                                 4.3
# 3                                                 4.4
# 4                                                 5.0
# ..                                                ...
# 57                                                NaN
# 58                                                2.6
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 AST.1  \
# 0                                                 1.5
# 1                                                 1.3
# 2                                                 2.6
# 3                                                 2.1
# 4                                                 1.0
# ..                                                ...
# 57                                                NaN
# 58                                                0.6
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                    WS  \
# 0                                                21.8
# 1                                                34.8
# 2                                                55.7
# 3                                                88.7
# 4                                                22.5
# ..                                                ...
# 57                                                NaN
# 58                                                0.3
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                 WS/48  \
# 0                                                .090
# 1                                                .092
# 2                                                .109
# 3                                                .122
# 4                                                .070
# ..                                                ...
# 57                                                NaN
# 58                                               .068
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                   BPM  \
# 0                                                -0.5
# 1                                                -0.9
# 2                                                 0.2
# 3                                                 0.8
# 4                                                -2.9
# ..                                                ...
# 57                                                NaN
# 58                                               -3.8
# 59                                                NaN
# 60  Milwaukee Bucks forfeited their Second Round p...
# 61      Miami Heat forfeited their Second Round pick.
#
#                                                  VORP  Year
# 0                                                 4.4  1989
# 1                                                 4.9  1989
# 2                                                13.5  1989
# 3                                                24.9  1989
# 4                                                -3.7  1989
# ..                                                ...   ...
# 57                                                NaN  2022
# 58                                               -0.1  2022
# 59                                                NaN  2022
# 60  Milwaukee Bucks forfeited their Second Round p...  2022
# 61      Miami Heat forfeited their Second Round pick.  2022
#
# [2054 rows x 23 columns]
